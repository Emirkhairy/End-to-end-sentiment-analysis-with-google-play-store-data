# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from google_play_scraper import app,Sort, reviews_all

# %%
Ipot_reviews = reviews_all(
            'com.indopremier.ipot',
            sleep_milliseconds = 0,
            lang = 'id',
            country = 'id',
            sort = Sort.NEWEST,

)

# %%
data = pd.DataFrame(np.array(Ipot_reviews), columns = ['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId         userName  \
# 0  df983f8b-3dc8-4b00-a62e-6da363100eb3      Ahmad Indra
# 1  767f2b9d-bd2e-48fc-9dcf-db7756d54d4d       Zydan Abli
# 2  bf6b9ede-99f5-4428-9843-08b7f88e7ff8  Rezza Tri Umami
# 3  935558f1-a92a-4d30-b7b6-3d0b98a15644    Wawan Gunawan
# 4  8296b2bf-a82b-4eea-864a-3d99a7429499     Rizky Bahari
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Lemot!.. buka Eazy Saham aja loading mulu. Mau...      1              0
# 1                             Appnya kenapa lemot ya      3              0
# 2  IPOT IPOTTT KOG LEMOOTT?!!! gak berubah-ubah d...      1              0
# 3  Assalamu'alaikum warahmatullahi Wabarokatuh be...      5              0
# 4  Sorry rubah bintang dari 5 jadi 2. Penarikan b...      2              0
#
#   reviewCreatedVersion                  at  \
# 0              9.9.137 2023-10-17 21:24:12
# 1                 None 2023-10-17 11:15:40
# 2                 None 2023-10-17 10:51:19
# 3              9.9.136 2023-10-17 00:41:20
# 4              9.9.136 2023-10-16 12:36:10
#
#                                         replyContent           repliedAt  \
# 0  Hi Ahmad. Mohon maaf atas ketidaknyamanasnnya.... 2023-10-18 09:20:05
# 1  Hi Zydan. Mohon maaf atas ketidaknyamanannya. ... 2023-10-17 11:55:37
# 2  Hi Rezza. Mohon maaf atas ketidaknyamanannya. ... 2023-10-17 11:44:23
# 3  Hi Wawan. Terima kasih atas review dan bintang... 2023-10-17 09:19:31
# 4  Hi Rizky. Mohon maaf atas ketidaknyamanannya. ... 2023-10-16 15:23:58
#
#   appVersion
# 0    9.9.137
# 1       None
# 2       None
# 3    9.9.136
# 4    9.9.136

# %%
data['at']=pd.to_datetime(data['at'])
data=data[data['at']>= '2023-01-01']
data
# Out:
#                                  reviewId          userName  \
# 0    df983f8b-3dc8-4b00-a62e-6da363100eb3       Ahmad Indra
# 1    767f2b9d-bd2e-48fc-9dcf-db7756d54d4d        Zydan Abli
# 2    bf6b9ede-99f5-4428-9843-08b7f88e7ff8   Rezza Tri Umami
# 3    935558f1-a92a-4d30-b7b6-3d0b98a15644     Wawan Gunawan
# 4    8296b2bf-a82b-4eea-864a-3d99a7429499      Rizky Bahari
# ..                                    ...               ...
# 695  500caa3b-b811-4055-b6c9-47218b4511fa            Yunita
# 696  4fb8a9a3-0366-48c8-8897-d77363f9b3ba  Komang Mahardika
# 697  92d92f2a-582e-42ed-b426-149074d1d34d  Yogi Adi Saputra
# 698  61a8c009-77b2-422b-88ac-6f140e115e2a       Herdin Saca
# 699  9c0f2727-d882-4a9a-a34b-b02c226ff5d7   Herry Syafriadi
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a/ACg8oc...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 695  https://play-lh.googleusercontent.com/a-/ALV-U...
# 696  https://play-lh.googleusercontent.com/a/ACg8oc...
# 697  https://play-lh.googleusercontent.com/a-/ALV-U...
# 698  https://play-lh.googleusercontent.com/a-/ALV-U...
# 699  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0    Lemot!.. buka Eazy Saham aja loading mulu. Mau...      1              0
# 1                               Appnya kenapa lemot ya      3              0
# 2    IPOT IPOTTT KOG LEMOOTT?!!! gak berubah-ubah d...      1              0
# 3    Assalamu'alaikum warahmatullahi Wabarokatuh be...      5              0
# 4    Sorry rubah bintang dari 5 jadi 2. Penarikan b...      2              0
# ..                                                 ...    ...            ...
# 695  Setelah minta bantuan admin akhirnya di update...      5             45
# 696              Apps nya keren.. Suksess untuk Ipot..      5              0
# 697  Apakah tidak ada fitur untuk penarikan dana me...      3              0
# 698  Saya mau daftar jdi investor mau pake sekurita...      4              0
# 699  Baru buat akun semua udah bener Pas mau login ...      1              0
#
#     reviewCreatedVersion                  at  \
# 0                9.9.137 2023-10-17 21:24:12
# 1                   None 2023-10-17 11:15:40
# 2                   None 2023-10-17 10:51:19
# 3                9.9.136 2023-10-17 00:41:20
# 4                9.9.136 2023-10-16 12:36:10
# ..                   ...                 ...
# 695              8.8.111 2023-01-04 10:48:19
# 696              8.8.111 2023-01-03 22:10:27
# 697              8.8.107 2023-01-01 20:28:44
# 698                 None 2023-01-01 10:31:09
# 699              8.8.107 2023-01-01 03:24:05
#
#                                           replyContent           repliedAt  \
# 0    Hi Ahmad. Mohon maaf atas ketidaknyamanasnnya.... 2023-10-18 09:20:05
# 1    Hi Zydan. Mohon maaf atas ketidaknyamanannya. ... 2023-10-17 11:55:37
# 2    Hi Rezza. Mohon maaf atas ketidaknyamanannya. ... 2023-10-17 11:44:23
# 3    Hi Wawan. Terima kasih atas review dan bintang... 2023-10-17 09:19:31
# 4    Hi Rizky. Mohon maaf atas ketidaknyamanannya. ... 2023-10-16 15:23:58
# ..                                                 ...                 ...
# 695  Hi Yunita. Mohon maaf atas ketidaknyamanannya.... 2023-01-03 14:30:49
# 696  \nHi Komang. Terima kasih atas review dan bint... 2023-01-04 09:48:12
# 697  Hi Yogi. Fitur penarikan dana melalui rekening... 2023-01-02 16:08:31
# 698  Hi Saca. Kami informasikan untuk rekening bank... 2023-01-01 16:12:35
# 699  Hi Herry. Pastikan ketik username terdiri dari... 2023-01-02 17:27:06
#
#     appVersion
# 0      9.9.137
# 1         None
# 2         None
# 3      9.9.136
# 4      9.9.136
# ..         ...
# 695    8.8.111
# 696    8.8.111
# 697    8.8.107
# 698       None
# 699    8.8.107
#
# [700 rows x 11 columns]

# %%
data.to_csv('data.csv',index=False)
